# %%
# --- JAGSoM Student Data Management (Interactive for Google Colab) ---

# List of placement-relevant courses
placement_courses = [
    "Business Analytics",
    "Digital Marketing",
    "Financial Modelling",
    "Data Science",
    "HR Analytics"
]

students = []

# Pre-defined student names
student_names = [
    "Aarav", "Meera", "Riya", "Kabir", "Sanya",
    "Ishaan", "Tanya", "Vivaan", "Nisha", "Rohan"
]

print("Placement-relevant courses:")
for c in placement_courses:
    print("-", c)

# Function to check placement readiness
def is_placement_ready(courses):
    return any(c in placement_courses for c in courses)

# Collect courses for each student
for i, name in enumerate(student_names, 1):
    print(f"\nEnter courses taken by {name} (Student {i}):")

    while True:
        courses_input = input("Courses (comma-separated): ").strip()
        courses = [c.strip().title() for c in courses_input.split(",") if c.strip()]

        if is_placement_ready(courses):
            students.append({
                "Name": name,
                "Courses Taken": courses
            })
            print(f"✅ Courses recorded: {', '.join(courses)}")
            break
        else:
            print("⚠️ Must include at least one placement-relevant course! Try again.")

print("\n✅ All 10 students added successfully!\n")

# Display all students
print("--- Student Data ---")
for student in students:
    print(f"Name: {student['Name']}, Courses: {', '.join(student['Courses Taken'])}")

# Display placement-ready status
print("\n--- Placement Readiness ---")
for student in students:
    status = "placement-ready" if is_placement_ready(student["Courses Taken"]) else "NOT placement-ready"
    print(f"{student['Name']} is {status}.")
# Out:
# Placement-relevant courses:
# - Business Analytics
# - Digital Marketing
# - Financial Modelling
# - Data Science
# - HR Analytics
#
# Enter courses taken by Aarav (Student 1):
# Courses (comma-separated): usiness Analytics
# ⚠️ Must include at least one placement-relevant course! Try again.
# Courses (comma-separated): Financial Modelling
# ✅ Courses recorded: Financial Modelling
#
# Enter courses taken by Meera (Student 2):
# Courses (comma-separated): Digital Marketing
# ✅ Courses recorded: Digital Marketing
#
# Enter courses taken by Riya (Student 3):
# Courses (comma-separated): Financial Modelling
# ✅ Courses recorded: Financial Modelling
#
# Enter courses taken by Kabir (Student 4):
# Courses (comma-separated): Financial Modelling
# ✅ Courses recorded: Financial Modelling
#
# Enter courses taken by Sanya (Student 5):
# Courses (comma-separated): HR Analytics
# ⚠️ Must include at least one placement-relevant course! Try again.
# Courses (comma-separated): HR Analytics
# ...

# %%
# --- Segment 1: Setup ---

# List of placement-relevant courses
placement_courses = [
    "Business Analytics",
    "Digital Marketing",
    "Financial Modelling",
    "Data Science",
    "HR Analytics"
]

# Pre-defined student names
student_names = [
    "Aarav", "Meera", "Riya", "Kabir", "Sanya",
    "Ishaan", "Tanya", "Vivaan", "Nisha", "Rohan"
]

# Display available courses
print("Placement-relevant courses:")
for c in placement_courses:
    print("-", c)

# Initialize empty list for student data
students = []
# Out:
# Placement-relevant courses:
# - Business Analytics
# - Digital Marketing
# - Financial Modelling
# - Data Science
# - HR Analytics

# %%
# --- Segment 2: Collect Student Courses ---

# Function to check placement readiness
def is_placement_ready(courses):
    courses_normalized = [c.lower() for c in courses]
    placement_normalized = [c.lower() for c in placement_courses]
    return any(c in placement_normalized for c in courses_normalized)

# Collect courses for each student
for i, name in enumerate(student_names, 1):
    print(f"\nEnter courses taken by {name} (Student {i}):")
    print(f"Available placement-relevant courses: {', '.join(placement_courses)}")

    while True:
        courses_input = input("Courses (comma-separated): ").strip()
        courses = [c.strip().title() for c in courses_input.split(",") if c.strip()]

        if is_placement_ready(courses):
            students.append({
                "Name": name,
                "Courses Taken": courses
            })
            print(f"✅ Courses recorded: {', '.join(courses)}")
            break
        else:
            print("⚠️ Must include at least one placement-relevant course! Try again.")
# Out:
# Enter courses taken by Aarav (Student 1):
# Available placement-relevant courses: Business Analytics, Digital Marketing, Financial Modelling, Data Science, HR Analytics
# Courses (comma-separated): Digital Marketing
# ✅ Courses recorded: Digital Marketing
#
# Enter courses taken by Meera (Student 2):
# Available placement-relevant courses: Business Analytics, Digital Marketing, Financial Modelling, Data Science, HR Analytics
# Courses (comma-separated): HR Analytics
# ✅ Courses recorded: Hr Analytics
#
# Enter courses taken by Riya (Student 3):
# Available placement-relevant courses: Business Analytics, Digital Marketing, Financial Modelling, Data Science, HR Analytics
# Courses (comma-separated):  Financial Modelling
# ✅ Courses recorded: Financial Modelling
#
# Enter courses taken by Kabir (Student 4):
# Available placement-relevant courses: Business Analytics, Digital Marketing, Financial Modelling, Data Science, HR Analytics
# Courses (comma-separated):  Financial Modelling
# ...

# %%
# --- Segment 3: Display Data ---

print("\n✅ All students added successfully!\n")

# Display all students
print("--- Student Data ---")
for student in students:
    print(f"Name: {student['Name']}, Courses: {', '.join(student['Courses Taken'])}")

# Display placement-ready status
print("\n--- Placement Readiness ---")
for student in students:
    status = "Placement-ready" if is_placement_ready(student["Courses Taken"]) else "NOT Placement-ready"
    print(f"{student['Name']} is {status}.")
# Out:
# ✅ All students added successfully!
#
# --- Student Data ---
# Name: Aarav, Courses: Digital Marketing
# Name: Meera, Courses: Hr Analytics
# Name: Riya, Courses: Financial Modelling
# Name: Kabir, Courses: Financial Modelling
# Name: Sanya, Courses: Data Science
# Name: Ishaan, Courses: Data Science
# Name: Tanya, Courses: Business Analytics
# Name: Vivaan, Courses: Business Analytics
# Name: Nisha, Courses: Financial Modelling
# Name: Rohan, Courses: Hr Analytics
#
# --- Placement Readiness ---
# Aarav is Placement-ready.
# Meera is Placement-ready.
# Riya is Placement-ready.
# Kabir is Placement-ready.
# Sanya is Placement-ready.
# Ishaan is Placement-ready.
# Tanya is Placement-ready.
# Vivaan is Placement-ready.
# Nisha is Placement-ready.
# Rohan is Placement-ready.
